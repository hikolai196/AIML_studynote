# %%
# !pip install umap-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 5.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Uniform Manifold Approximation and Projection (UMAP)

# %% [markdown]
# UMAP is another non-linear dimensionality reduction technique that is similar to t-SNE but often faster and better at preserving the global structure of the data. It is also used for visualizing high-dimensional data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import umap

# %% [markdown]
# # Load the Iris dataset

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# ## Standardize the data (mean=0, variance=1)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Perform UMAP

# %%
umap_model = umap.UMAP(n_components=2, random_state=42)
X_umap = umap_model.fit_transform(X_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %% [markdown]
# # Plot the UMAP results

# %%
plt.figure(figsize=(8, 6))
markers = ['o', '+', '^']  # 'o' for setosa, '+' for versicolor, '^' for virginica
for target, marker in zip(np.unique(y), markers):
    plt.scatter(X_umap[y == target, 0], X_umap[y == target, 1], label=iris.target_names[target], marker=marker)
plt.xlabel('UMAP Component 1')
plt.ylabel('UMAP Component 2')
plt.legend()
plt.title('UMAP of Iris Dataset')
plt.show()
