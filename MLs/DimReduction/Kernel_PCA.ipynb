# %% [markdown]
# # Kernel PCA

# %% [markdown]
# Kernel PCA is an extension of PCA that uses kernel methods to perform the dimensionality reduction in a non-linear manner. It is useful for datasets where the relationship between features is non-linear.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA

# %% [markdown]
# # Load the Iris dataset

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# ## Standardize the data (mean=0, variance=1)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Perform Kernel PCA

# %%
kpca = KernelPCA(n_components=2, kernel='rbf', gamma=15)
X_kpca = kpca.fit_transform(X_scaled)

# %% [markdown]
# # Plot the Kernel PCA results

# %%
plt.figure(figsize=(8, 6))
markers = ['o', '+', '^']  # 'o' for setosa, '+' for versicolor, '^' for virginica
for target, marker in zip(np.unique(y), markers):
  plt.scatter(X_kpca[y == target, 0], X_kpca[y == target, 1], label=iris.target_names[target], marker=marker)
plt.xlabel('Kernel PCA Component 1')
plt.ylabel('Kernel PCA Component 2')
plt.legend()
plt.title('Kernel PCA of Iris Dataset')
plt.show()
