# %% [markdown]
# # Independent Component Analysis (ICA)

# %% [markdown]
# ICA is a computational method for separating a multivariate signal into additive, independent components. It is used in various fields such as signal processing and neuroscience.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import FastICA

# %% [markdown]
# # Load the Iris dataset

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# ## Standardize the data (mean=0, variance=1)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Perform ICA

# %%
ica = FastICA(n_components=2, random_state=42)
X_ica = ica.fit_transform(X_scaled)

# %% [markdown]
# # Plot the ICA results

# %%
plt.figure(figsize=(8, 6))
markers = ['o', '+', '^']  # 'o' for setosa, '+' for versicolor, '^' for virginica
for target, marker in zip(np.unique(y), markers):
  plt.scatter(X_ica[y == target, 0], X_ica[y == target, 1], label=iris.target_names[target], marker=marker)
plt.xlabel('ICA Component 1')
plt.ylabel('ICA Component 2')
plt.legend()
plt.title('ICA of Iris Dataset')
plt.show()
